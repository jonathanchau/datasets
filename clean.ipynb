# %%
import pandas as pd
df = pd.read_csv("MPI-Data-Hub_EduAttainment-Nativity & byCOB_2021.csv")
df.head(10)
# Out:
#   Educational Attainment of U.S. Adults (ages 25 and over) by Nativity and Select Country of Birth, 2021  \
# 0                                                NaN
# 1                                                NaN
# 2                                          U.S. Born
# 3                                         Immigrants
# 4                                                NaN
# 5              Immigrants by Select Country of Birth
# 6                                             Mexico
# 7                                              India
# 8                                    China/Hong Kong
# 9                                        Philippines
#
#       Unnamed: 1           Unnamed: 2       Unnamed: 3  \
# 0            NaN                  NaN              NaN
# 1     All Adults  Less than 9th Grade  9th-12th Grade
# 2   188,082,000                    2%               5%
# 3    40,208,000                   16%               9%
# ...
